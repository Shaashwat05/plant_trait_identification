# %%
import re
import pandas as pd
import numpy as np
import subprocess
import wget
import re

# %%
data = pd.read_csv('TRY_final.txt', sep=',', encoding='latin-1')
data.head()
# Out:
#           AccSpeciesName    mean_14  mean_3117  mean_3106    mean_4  \
# 0                     Aa  26.400000   9.433962        NaN       NaN
# 1  Aaronsohnia pubescens        NaN        NaN        0.2       NaN
# 2         ABACABA (PALM)        NaN        NaN       15.0       NaN
# 3     Abarema adenophora  24.422045  11.820481        NaN  0.663459
# 4    Abarema adenophorum        NaN        NaN        NaN  0.360000
#
#    mean_3110  mean_26  stddev_14   stddev_3117  stddev_3106  stddev_4  \
# 0        NaN      NaN   0.000000  2.832447e-11          NaN       NaN
# 1        NaN      NaN        NaN           NaN          NaN       NaN
# 2        NaN      NaN        NaN           NaN     8.485281       NaN
# 3   56861.99      NaN   1.593152  1.030987e+00          NaN  0.132959
# 4        NaN      NaN        NaN           NaN          NaN  0.000000
#
#    stddev_3110  stddev_26 PlantGrowthForm
# 0          NaN        NaN             NaN
# 1          NaN        NaN             NaN
# ...

# %%
links = pd.read_csv('species_links.txt', sep=',', encoding='latin-1')
links.head()
# Out:
#       gbifID                                         identifier  \
# 0  891019180  https://static.inaturalist.org/photos/73239/or...
# 1  891019180  https://static.inaturalist.org/photos/73240/or...
# 2  891019290  https://static.inaturalist.org/photos/80340/or...
# 3  891019325  https://static.inaturalist.org/photos/82422/or...
# 4  891019575  https://static.inaturalist.org/photos/97085/or...
#
#                   species  decimalLatitude  decimalLongitude  \
# 0  Polypodium virginianum        41.310674        -72.513289
# 1  Polypodium virginianum        41.310674        -72.513289
# 2        Pastinaca sativa        44.002331        -73.169975
# 3            Datura metel        16.023604        -16.489864
# 4  Polypodium virginianum        44.032032        -73.085672
#
#    coordinateUncertaintyInMeters   bio1   bio2  bio3     bio4  ...  bio10  \
# 0                            NaN  103.0  102.0  29.0   8513.0  ...  211.0
# ...

# %%
# IMages taken from the Chicago / Illinois 
links.loc[(np.floor(links['decimalLatitude'])) == 41 & (np.floor(links['decimalLongitude']) == 87)]
# Out:
#              gbifID                                         identifier  \
# 21804    1065600710  https://static.inaturalist.org/photos/1518570/...
# 39421    1144277960  https://static.inaturalist.org/photos/2261120/...
# 59095    1265559785  https://static.inaturalist.org/photos/3304060/...
# 59096    1265559785  https://static.inaturalist.org/photos/3304057/...
# 104912   1453059910  https://static.inaturalist.org/photos/2066531/...
# ...             ...                                                ...
# 9886508  2641542777  https://static.inaturalist.org/photos/77197021...
# 9888216  2641568557  https://static.inaturalist.org/photos/78025813...
# 9888799  2641578302  https://static.inaturalist.org/photos/77733091...
# 9890026  2641597347  https://static.inaturalist.org/photos/77807332...
# 9891831  2641626412  https://static.inaturalist.org/photos/77807971...
#
#                               species  decimalLatitude  decimalLongitude  \
# ...

# %%
base_url = 'https://inaturalist-open-data.s3.amazonaws.com/photos/'
for link in range(len(links['identifier'])):
    val = re.findall(r'\d+', links['identifier'][i])

    if len(val) == 1:
        url = base_url + val[0] +'/medium.jpg'
    else:
        url = base_url + val[0] +'/medium.jpg?' + val[1]

    try:
        wget.download(url, out='images/'+links['species'][i]+'.jpg')
    except:
        continue
# Out:
# https://inaturalist-open-data.s3.amazonaws.com/photos/73240/medium.jpg?1444445547
# https://inaturalist-open-data.s3.amazonaws.com/photos/80340/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/82422/medium.jpg?1444458986
# https://inaturalist-open-data.s3.amazonaws.com/photos/97085/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/111658/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/115961/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/120167/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/120169/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/119762/medium.jpg?1444497845
# https://inaturalist-open-data.s3.amazonaws.com/photos/122795/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/125102/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/130454/medium.jpg
# https://inaturalist-open-data.s3.amazonaws.com/photos/131400/medium.jpg
# ...
